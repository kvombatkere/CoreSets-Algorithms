# %%
## Median Approximation Testing
## Karan Vombatkere, Dec 2021

#Imports
import numpy as np
import matplotlib.pyplot as plt

import sys
sys.path.append('../algorithms/')

import coreset_median as c_median

# %%
# n_vals = np.logspace(1, 10, 10)
# n_vals

# %%
#Test median estimation
n_range = np.logspace(1, 10, 10)
n_vals = n_range[1:7]
epsilon = 0.05

approxMedians = []
trueMedians = []

approxRuntimes = []
trueRuntimes = []

shape, scale = 5., 50.

for n in n_vals:
    print(n)

    #Use a random gamma distribution for median
    n_array = np.random.gamma(shape, scale, int(n))

    median_approx_n = c_median.Coreset_Median(n_array, epsilon)
    median_approx_n.compute_median()

    #Extract medians + metrics
    approxMedians.append(median_approx_n.approxMedianVal)
    trueMedians.append(median_approx_n.trueMedian)

    approxRuntimes.append(median_approx_n.runTime)
    trueRuntimes.append(median_approx_n.np_runTime)
# Out:
# 100.0
# 4
# Total elements checked = 21
# Median value approximation = 238.8950638425805
# Median approximation computation time = 0.00013 seconds
# True Median = 243.44158814768582
# Numpy Median computation time = 0.00127 seconds
# 1000.0
# 47
# Total elements checked = 21
# Median value approximation = 237.63528133899703
# Median approximation computation time = 0.00041 seconds
# True Median = 231.6610192563923
# Numpy Median computation time = 0.00051 seconds
# 10000.0
# 476
# Total elements checked = 21
# Median value approximation = 238.902618480867
# Median approximation computation time = 0.00015 seconds
# True Median = 232.8131430624955
# Numpy Median computation time = 0.00110 seconds
# 100000.0
# 4761
# Total elements checked = 21
# Median value approximation = 239.83513648950515
# Median approximation computation time = 0.00016 seconds
# True Median = 233.48384535713745
# Numpy Median computation time = 0.01897 seconds
# 1000000.0
# 47619
# Total elements checked = 21
# Median value approximation = 240.0647675970355
# Median approximation computation time = 0.00044 seconds
# True Median = 233.58887463681714
# Numpy Median computation time = 0.20237 seconds
# 10000000.0
# 476190
# Total elements checked = 21
# Median value approximation = 240.00083430958017
# Median approximation computation time = 0.00020 seconds
# True Median = 233.54071504178614
# Numpy Median computation time = 2.70928 seconds

# %%
fig = plt.figure(figsize=(8, 6), dpi=80)
plt.plot(n_vals, approxRuntimes, color = 'blue', marker='*', label='Approx runtime')
plt.plot(n_vals, trueRuntimes, color = 'green', marker='+', label='True runtime')

plt.legend(loc='upper left', fontsize=9)
plt.xscale('log')
plt.yscale('log')


title_text = 'Approximate and True Median Runtimes, epsilon={}'.format(epsilon)
plt.title(title_text, fontsize=11)
plt.ylabel('Runtime (s)')
plt.xlabel('n')
# Out:
# Text(0.5, 0, 'n')

# %%
fig = plt.figure(figsize=(8, 6), dpi=80)
plt.plot(n_vals, approxMedians, color = 'blue', marker='*', label='Approx median')
plt.plot(n_vals, trueMedians, color = 'green', marker='+', label='True median')

plt.legend(loc='upper right', fontsize=9)
plt.xscale('log')

title_text = 'Approximate and True Median Values, epsilon={}'.format(epsilon)
plt.title(title_text, fontsize=11)
plt.ylabel('Median Value')
plt.xlabel('n')
# Out:
# Text(0.5, 0, 'n')
